# %%
import pandas as pd

fiis = pd.read_csv('./data/statusinvest-busca-avancada.csv', sep=';', decimal=',', thousands='.', encoding='utf-8')

fiis.head()

fiis
# Out:
#      TICKER   PRECO  ULTIMO DIVIDENDO     DY  VALOR PATRIMONIAL COTA  P/VP  \
# 0    ABCP11   80.37          0.650000   9.58                  110.80  0.72
# 1    AFHI11   96.58          1.010000  12.53                   94.56  1.02
# 2    AIEC11   54.10          0.340000   7.35                   76.57  0.71
# 3    AJFI11    8.20          0.050000   8.19                   11.11  0.74
# 4    ALMI11  645.00          4.530000   7.11                 2062.46  0.31
# ..      ...     ...               ...    ...                     ...   ...
# 593  YUFI11   15.00          0.171599   4.61                   45.55  0.33
# 594  ZAGH11    9.30          0.059000   7.88                    9.11  1.10
# 595  ZAVC11    8.85          0.120000  17.51                   10.13  0.87
# 596  ZAVI11   10.07          0.110000  12.98                   13.57  0.76
# 597  ZIFI11  900.00          3.304958   0.00                 1757.66  0.51
#
# ...
